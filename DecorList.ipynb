# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 4.7

# %%
from art import *

# %% [markdown]
# ## Decoration Counter

# %%
DECORATION_COUNTER
# Out:
# 195

# %% [markdown]
# ⚠️ Some environments don't support all decorations

# %% [markdown]
# ## Decoration List

# %%
decor_list()
# Out:
# angry1
#   ୧༼ಠ益ಠ༽︻╦╤─ƭεรƭ
# ******************************
# arrow1
# ➶➶➶➶➶ƭεรƭ➷➷➷➷➷
# ******************************
# arrow2
# ↤↤↤↤↤ƭεรƭ↦↦↦↦↦
# ******************************
# arrow3
# ↫↫↫↫↫ƭεรƭ↬↬↬↬↬
# ******************************
# arrow4
# –--´¯`----»ƭεรƭ«----´¯`–--
# ******************************
# arrow5
# ‹—•°º¤°(ƭεรƭ)°¤º°•—›
# ******************************
# arrow6
# ⇇⇇⇇ƭεรƭ⇉⇉⇉
# ******************************
# arrow7
# ⇉⇉⇉ƭεรƭ⇇⇇⇇
# ******************************
# arrow8
# ]|I{•------» [ƭεรƭ] «------•}I|[
# ******************************
# arrow_wave1
# (¯`·.¸¸.·´¯`·.¸¸.-> [ƭεรƭ<-.¸¸.·´¯`·.¸¸.·´¯)
# ******************************
# arrow_wave2
# °·.¸.·°¯°·.¸.·°¯°·.¸.-> [ƭεรƭ] <-.¸.·°¯°·.¸.·°¯°·.¸.·°
# ******************************
# ball1
# ●●--●●--●●ƭεรƭ●●--●●--●●
# ******************************
# ball2
# ··●(`●-ƭεรƭ-●´)●··
# ******************************
# ball3
# ●·(¯¨°¹●.ƭεรƭ.●¹°¨¯)·●
# ******************************
# barcode1
# ▌│█║▌║▌║ ƭεรƭ ║▌║▌║█│▌
# ...

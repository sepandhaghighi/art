# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 3.6

# %%
from art import *

# %% [markdown]
# ## Art Counter

# %%
ART_COUNTER
# Out:
# 350

# %% [markdown]
# ## Art List

# %%
art_list()
# Out:
# 100$
# [̲̅$̲̅(̲̅ιοο̲̅)̲̅$̲̅]
# ******************************
# 3
# ᕙ༼ ,,ԾܫԾ,, ༽ᕗ
# ******************************
# 5
# ᕙ༼ ,,இܫஇ,, ༽ᕗ
# ******************************
# 9/11 truth
# ✈__✈ █ █ ▄
# ******************************
# afraid
# (　ﾟ Дﾟ)
# ******************************
# airplane1
#  ‛¯¯٭٭¯¯(▫▫)¯¯٭٭¯¯’
# ******************************
# airplane2
# ✈
# ******************************
# ak-47
# ︻┳デ═—
# ******************************
# aliens
# (<>..<>)
# ******************************
# almost cared
# ╰╏ ◉ 〜 ◉ ╏╯
# ******************************
# american money
# [($)]
# ******************************
# angel
# ^i^
# ******************************
# angry
#  ლ(ಠ益ಠ)ლ
# ******************************
# angry face
# (⋟﹏⋞)
# ******************************
# angry2
# ( ͠° ͟ʖ ͡°)﻿
# ******************************
# ankush
# ︻デ┳═ー*----*
# ******************************
# arrow
# »»---------------------►
# ******************************
# atish
# (| - _ - |)
# ...

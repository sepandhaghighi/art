# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 1.1

# %% [markdown]
# ## Art List

# %%
from art import *

# %%
aprint_test()
# Out:
# 100$
# [̲̅$̲̅(̲̅ιοο̲̅)̲̅$̲̅]
# ******************************
# airplane1
#  ‛¯¯٭٭¯¯(▫▫)¯¯٭٭¯¯’
# ******************************
# airplane2
# ✈
# ******************************
# angry_face
# (⋟﹏⋞)
# ******************************
# arrow
# »»---------------------►
# ******************************
# atish
# (| - _ - |)
# ******************************
# awesome
# <:3 )~~~
# ******************************
# bear
# ʕ•ᴥ•ʔ
# ******************************
# big_eyes
# ⺌∅‿∅⺌
# ******************************
# big_nose
# ˚∆˚
# ******************************
# bird
#  (⌒▽⌒)﻿
# ******************************
# birds
# ~(‾▿‾)~
# ******************************
# boobs
# (.)(.)
# ******************************
# boom_box
# ♫♪.ılılıll|̲̅̅●̲̅̅|̲̅̅=̲̅̅|̲̅̅●̲̅̅|llılılı.♫♪
# ******************************
# bullshit
# |3ᵕᶦᶦᶳᶣᶨᶵ
# ******************************
# butterfly
# Ƹ̵̡Ӝ̵̨̄Ʒ
# ******************************
# car_race
# |[●▪▪●]|
# ******************************
# care_crowd
# ...

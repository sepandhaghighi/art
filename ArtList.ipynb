# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.0

# %% [markdown]
# ## Art List

# %%
from art import *

# %%
art_list()
# Out:
# 100$
# [̲̅$̲̅(̲̅ιοο̲̅)̲̅$̲̅]
# ******************************
# 3
# ᕙ༼ ,,ԾܫԾ,, ༽ᕗ
# ******************************
# 5
# ᕙ༼ ,,இܫஇ,, ༽ᕗ
# ******************************
# 9/11 truth
# ✈__✈ █ █ ▄
# ******************************
# AK-47
# ︻┳デ═—
# ******************************
# I kill you
#  ̿ ̿̿'̿̿\̵͇̿̿\=(•̪●)=/̵͇̿̿/'̿̿ ̿ ̿
# ******************************
# airplane1
#  ‛¯¯٭٭¯¯(▫▫)¯¯٭٭¯¯’
# ******************************
# airplane2
# ✈
# ******************************
# angry
#  ლ(ಠ益ಠ)ლ
# ******************************
# angry face
# (⋟﹏⋞)
# ******************************
# angry2
# ( ͠° ͟ʖ ͡°)﻿
# ******************************
# ankush
# ︻デ┳═ー*----*
# ******************************
# arrow
# »»---------------------►
# ******************************
# atish
# (| - _ - |)
# ******************************
# awesome
# <:3 )~~~
# ******************************
# badass
# (⌐■_■)--︻╦╤─ - - -
# ******************************
# bagel
# nln >_< nln
# ******************************
# ...

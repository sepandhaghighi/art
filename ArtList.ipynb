# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 4.7

# %%
from art import *

# %% [markdown]
# ## Art Counter

# %%
ART_COUNTER
# Out:
# 499

# %% [markdown]
# ## Art List

# %%
art_list()
# Out:
# 3
# ᕙ༼ ,,ԾܫԾ,, ༽ᕗ
# ******************************
# 5
# ᕙ༼ ,,இܫஇ,, ༽ᕗ
# ******************************
# 9/11 truth
# ✈__✈ █ █ ▄
# ******************************
# acid
# ⊂(◉‿◉)つ
# ******************************
# afraid
# (　ﾟ Дﾟ)
# ******************************
# airplane1
#  ‛¯¯٭٭¯¯(▫▫)¯¯٭٭¯¯’
# ******************************
# airplane2
# ✈
# ******************************
# ak-47
# ︻┳デ═—
# ******************************
# alien
# ::)
# ******************************
# almost cared
# ╰╏ ◉ 〜 ◉ ╏╯
# ******************************
# american money1
# [($)]
# ******************************
# american money2
# [̲̅$̲̅(̲̅1̲̅)̲̅$̲̅]
# ******************************
# american money3
# [̲̅$̲̅(̲̅5̲̅)̲̅$̲̅]
# ******************************
# american money4
# [̲̅$̲̅(̲̅ιοο̲̅)̲̅$̲̅]
# ******************************
# american money5
# [̲̅$̲̅(̲̅2οο̲̅)̲̅$̲̅]
# ******************************
# angel1
# ^i^
# ******************************
# angel2
# O:-)
# ******************************
# ...

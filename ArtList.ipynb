# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 1.5

# %% [markdown]
# ## Art List

# %%
from art import *

# %%
art_list()
# Out:
# 100$
# [̲̅$̲̅(̲̅ιοο̲̅)̲̅$̲̅]
# ******************************
# 3
# ᕙ༼ ,,ԾܫԾ,, ༽ᕗ
# ******************************
# 5
# ᕙ༼ ,,இܫஇ,, ༽ᕗ
# ******************************
# airplane1
#  ‛¯¯٭٭¯¯(▫▫)¯¯٭٭¯¯’
# ******************************
# airplane2
# ✈
# ******************************
# angry face
# (⋟﹏⋞)
# ******************************
# angry2
# ( ͠° ͟ʖ ͡°)﻿
# ******************************
# ankush
# ︻デ┳═ー*----*
# ******************************
# arrow
# »»---------------------►
# ******************************
# atish
# (| - _ - |)
# ******************************
# awesome
# <:3 )~~~
# ******************************
# bagel
# nln >_< nln
# ******************************
# bear
# ʕ•ᴥ•ʔ
# ******************************
# bee
# ¸.·´¯`·¸¸.·´¯`·.¸.-<\^}0=:
# ******************************
# big eyes
# ⺌∅‿∅⺌
# ******************************
# big nose
# ˚∆˚
# ******************************
# bird
#  (⌒▽⌒)﻿
# ******************************
# birds
# ~(‾▿‾)~
# ...

# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.3

# %%
from art import *

# %% [markdown]
# ## Font Counter

# %%
font_counter
# Out:
# 225

# %% [markdown]
# ## Font List

# %%
font_list()
# Out:
# 1row :
# ~|~ [- _\~ ~|~
#
#
# 3-d :
#    **                     **
#   /**                    /**
#  ******  *****   ****** ******
# ///**/  **///** **//// ///**/
#   /**  /*******//*****   /**
#   /**  /**////  /////**  /**
#   //** //****** ******   //**
#    //   ////// //////     //
#
# 3d_diagonal :
#
#
#     ___                                 ___
#   ,--.'|_                             ,--.'|_
#   |  | :,'                            |  | :,'
#   :  : ' :               .--.--.      :  : ' :
# .;__,'  /      ,---.    /  /    '   .;__,'  /
# |  |   |      /     \  |  :  /`./   |  |   |
# :__,'| :     /    /  | |  :  ;_     :__,'| :
#   '  : |__  .    ' / |  \  \    `.    '  : |__
#   |  | '.'| '   ;   /|   `----.   \   |  | '.'|
#   ;  :    ; '   |  / |  /  /`--'  /   ;  :    ;
#   |  ,   /  |   :    | '--'.     /    |  ,   /
#    ---`-'    \   \  /    `--'---'      ---`-'
#               `----'
#
#
# 3x5 :
#
#  #           #
# ### ###  ## ###
#  #  ##   #   #
#  ## ### ##   ##
# ...

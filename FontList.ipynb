# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.7

# %%
from art import *

# %% [markdown]
# ## Font Counter

# %%
font_counter
# Out:
# 300

# %% [markdown]
# ## Font List

# %%
font_list("art 2.7")
# Out:
# 1943 :
#          ### # #  ### # #           ## ##     #  #    ######
#          ### # #  ### # #           ##  ##   ### #    ##   #
#          ### # #  ### # #               ##   ## #        ##
#    ## ## ### # #  ### # #              ##    #   #      ##
# #  ## ## ### # #  ### # #             ##      #  #      ##
# ####  ## ### # #  ### # #            #   ##  ### #      ##
#  ##   ## ### # #  ### # #           ######   ### #      ##
#  ##   ## ### # #  ### # #                    ### #
#
# 1row :
# /\ /? ~|~   ^/_ "/
#
#
# 3-d :
#                     **      ****     ******
#                    /**     */// *   //////*
#   ******   ****** ******  /    /*        /*
#  //////** //**//*///**/      ***         *
#   *******  /** /   /**      *//         *
#  **////**  /**     /**     *      **   *
# //********/***     //**   /******/**  *
#  //////// ///       //    ////// //  /
#
# 3d_diagonal :
#                                                                      ,----,
# ...

# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.7

# %%
from art import *

# %% [markdown]
# ## Font Counter

# %%
font_counter
# Out:
# 280

# %% [markdown]
# ## Font List

# %%
font_list("art 2.6")
# Out:
# 1943 :
#          ### # #  ### # #           ## ##     #  #     ## ###
#          ### # #  ### # #           ##  ##   ### #    ##   ##
#          ### # #  ### # #               ##   ## #     ##
#    ## ## ### # #  ### # #              ##    #   #    ## ###
# #  ## ## ### # #  ### # #             ##      #  #    ##   ##
# ####  ## ### # #  ### # #            #   ##  ### #    ##   ##
#  ##   ## ### # #  ### # #           ######   ### #     ## ##
#  ##   ## ### # #  ### # #                    ### #
#
# 1row :
# /\ /? ~|~   ^/_ (o
#
#
# 3-d :
#                     **      ****      ****
#                    /**     */// *    */// *
#   ******   ****** ******  /    /*   /*   /
#  //////** //**//*///**/      ***    /*****
#   *******  /** /   /**      *//     /*/// *
#  **////**  /**     /**     *      **/*   /*
# //********/***     //**   /******/**/ ****
#  //////// ///       //    ////// //  ////
#
# 3d_diagonal :
#
#
#                             ___             ,----,
# ...

# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.0

# %% [markdown]
# ## Font List

# %%
from art import *

# %%
font_list()
# Out:
# 1row :
# ~|~ [- _\~ ~|~
#
#
# 3-d :
#    **                     **
#   /**                    /**
#  ******  *****   ****** ******
# ///**/  **///** **//// ///**/
#   /**  /*******//*****   /**
#   /**  /**////  /////**  /**
#   //** //****** ******   //**
#    //   ////// //////     //
#
# 3d_diagonal :
#
#
#     ___                                 ___
#   ,--.'|_                             ,--.'|_
#   |  | :,'                            |  | :,'
#   :  : ' :               .--.--.      :  : ' :
# .;__,'  /      ,---.    /  /    '   .;__,'  /
# |  |   |      /     \  |  :  /`./   |  |   |
# :__,'| :     /    /  | |  :  ;_     :__,'| :
#   '  : |__  .    ' / |  \  \    `.    '  : |__
#   |  | '.'| '   ;   /|   `----.   \   |  | '.'|
#   ;  :    ; '   |  / |  /  /`--'  /   ;  :    ;
#   |  ,   /  |   :    | '--'.     /    |  ,   /
#    ---`-'    \   \  /    `--'---'      ---`-'
#               `----'
#
#
# 3x5 :
#
#  #           #
# ### ###  ## ###
#  #  ##   #   #
#  ## ### ##   ##
# ...

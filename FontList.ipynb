# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 3.0

# %%
from art import *

# %% [markdown]
# ## Font Counter

# %%
font_counter
# Out:
# 360

# %% [markdown]
# ## Font List

# %%
font_list("art 3.0")
# Out:
# 1943 :
#          ### # #  ### # #            ## ##    #  #     ## ##
#          ### # #  ### # #           ##   ##  ### #    ##   ##
#          ### # #  ### # #                ##  ## #     ##   ##
#    ## ## ### # #  ### # #              ###   #   #    ##   ##
# #  ## ## ### # #  ### # #                ##   #  #    ##   ##
# ####  ## ### # #  ### # #           ##   ##  ### #    ##   ##
#  ##   ## ### # #  ### # #            ## ##   ### #     ## ##
#  ##   ## ### # #  ### # #                    ### #
#
# 1row :
# /\ /? ~|~   -} (\)
#
#
# 3-d :
#                     **      ****      ****
#                    /**     */// *    *///**
#   ******   ****** ******  /    /*   /*  */*
#  //////** //**//*///**/      ***    /* * /*
#   *******  /** /   /**      /// *   /**  /*
#  **////**  /**     /**     *   /* **/*   /*
# //********/***     //**   / **** /**/ ****
#  //////// ///       //     ////  //  ////
#
# 3d_diagonal :
#
#                                         .--,-``-.
# ...

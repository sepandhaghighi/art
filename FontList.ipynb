# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 0.8

# %% [markdown]
# ## Font List

# %%
from art import *

# %%
font_list()
# Out:
# 3-d :
#    **                     **
#   /**                    /**
#  ******  *****   ****** ******
# ///**/  **///** **//// ///**/
#   /**  /*******//*****   /**
#   /**  /**////  /////**  /**
#   //** //****** ******   //**
#    //   ////// //////     //
#
# 3x5 :
#
#  #           #
# ### ###  ## ###
#  #  ##   #   #
#  ## ### ##   ##
#
#
# 5lineoblique :
#
#
#
#  __  ___     ___        ___     __  ___
#   / /      //___) )   ((   ) )   / /
#  / /      //           \ \      / /
# / /      ((____     //   ) )   / /
#
# acrobatic :
#   o                               o
#  <|>                             <|>
#  < >                             < >
#   |        o__  __o       __o__   |
#   o__/_   /v      |>     />  \    o__/_
#   |      />      //      \o       |
#   |      \o    o/         v\      |
#   o       v\  /v __o       <\     o
#   <\__     <\/> __/>  _\o__</     <\__
#
#
#
#
# alligator :
#   :::::::::::       ::::::::::       ::::::::   :::::::::::
# ...

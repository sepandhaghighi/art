# %% [markdown]
# # ART

# %% [markdown]
# ### Version : 2.9

# %%
from art import *

# %% [markdown]
# ## Font Counter

# %%
font_counter
# Out:
# 340

# %% [markdown]
# ## Font List

# %%
font_list("art 2.9")
# Out:
# 1943 :
#          ### # #  ### # #           ## ##     #  #     ## ##
#          ### # #  ### # #           ##  ##   ### #     #   ##
#          ### # #  ### # #               ##   ## #     ##   ##
#    ## ## ### # #  ### # #              ##    #   #     ## ###
# #  ## ## ### # #  ### # #             ##      #  #         ##
# ####  ## ### # #  ### # #            #   ##  ### #    ##   ##
#  ##   ## ### # #  ### # #           ######   ### #     ## ##
#  ##   ## ### # #  ### # #                    ### #
#
# 1row :
# /\ /? ~|~   ^/_ "|
#
#
# 3-d :
#                     **      ****      ****
#                    /**     */// *    */// *
#   ******   ****** ******  /    /*   /*   /*
#  //////** //**//*///**/      ***    / ****
#   *******  /** /   /**      *//      ///*
#  **////**  /**     /**     *      **   *
# //********/***     //**   /******/**  *
#  //////// ///       //    ////// //  /
#
# 3d_diagonal :
#
#                                                                ,---.-,
# ...
